# %% [markdown]
# <a href="https://colab.research.google.com/github/SzymonCisowski/PFML_Project/blob/master/Projekt_PFML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data2023_08 = pd.read_csv('drive/MyDrive/apartments_pl_2023_08.csv')
data2023_09 = pd.read_csv('drive/MyDrive/apartments_pl_2023_09.csv')
data2023_10 = pd.read_csv('drive/MyDrive/apartments_pl_2023_10.csv')

# %%
data2023_10.describe()
# Out:
#        squareMeters         rooms         floor    floorCount     buildYear  \
# count  16690.000000  16690.000000  13644.000000  16448.000000  13785.000000
# mean      58.985279      2.680228      3.268030      5.162755   1984.573957
# std       21.347723      0.911191      2.455211      3.201862     34.164553
# min       25.000000      1.000000      1.000000      1.000000   1851.000000
# 25%       44.402500      2.000000      2.000000      3.000000   1965.000000
# 50%       55.000000      3.000000      3.000000      4.000000   1992.000000
# 75%       69.000000      3.000000      4.000000      6.000000   2015.000000
# max      150.000000      6.000000     29.000000     29.000000   2023.000000
#
#            latitude     longitude  centreDistance      poiCount  \
# count  16690.000000  16690.000000    16690.000000  16690.000000
# mean      52.047413     19.489039        4.328341     20.462912
# std        1.331076      1.779749        2.879183     24.104101
# ...

# %%
data = [data2023_08, data2023_09, data2023_10]
df = pd.concat(data)
print(df.shape)
df.describe()
df
# Out:
# (52592, 28)
#                                      id       city          type  \
# 0      f8524536d4b09a0c8ccc0197ec9d7bde   szczecin  blockOfFlats
# 1      accbe77d4b360fea9735f138a50608dd   szczecin  blockOfFlats
# 2      8373aa373dbc3fe7ca3b7434166b8766   szczecin      tenement
# 3      0a68cd14c44ec5140143ece75d739535   szczecin      tenement
# 4      f66320e153c2441edc0fe293b54c8aeb   szczecin  blockOfFlats
# ...                                 ...        ...           ...
# 16685  1e7f4f1fdfea31eb84e071d697839632  bydgoszcz           NaN
# 16686  d971c4ed3aab9919bf203e96019a678e  bydgoszcz      tenement
# 16687  60fcbfa2a2a48ebcc2e554efba7f2729  bydgoszcz      tenement
# 16688  cd0241b70b79aaaf767a0dd3a7cfbb31  bydgoszcz           NaN
# 16689  1cdf62d567c6be2fa488f16ad9939c3a  bydgoszcz  blockOfFlats
#
#        squareMeters  rooms  floor  floorCount  buildYear   latitude  \
# 0             63.00    3.0    4.0        10.0     1980.0  53.378933
# ...

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#                                      id       city          type  \
# 0      f8524536d4b09a0c8ccc0197ec9d7bde   szczecin  blockOfFlats
# 1      accbe77d4b360fea9735f138a50608dd   szczecin  blockOfFlats
# 2      8373aa373dbc3fe7ca3b7434166b8766   szczecin      tenement
# 3      0a68cd14c44ec5140143ece75d739535   szczecin      tenement
# 4      f66320e153c2441edc0fe293b54c8aeb   szczecin  blockOfFlats
# ...                                 ...        ...           ...
# 35227  f4f6e61a07541e8397d4baff8b770e0a  bydgoszcz      tenement
# 35228  15b7903dd521db04aae25831d5e6195d  bydgoszcz           NaN
# 35229  37c32bd102f6da4e24ae0caf366f1a9a  bydgoszcz  blockOfFlats
# 35230  a250aefc84e4567190067f387f56e966  bydgoszcz           NaN
# 35231  6a4b30b5fcdee00bfe5bcc0da82df9b1  bydgoszcz  blockOfFlats
#
#        squareMeters  rooms  floor  floorCount  buildYear   latitude  \
# 0             63.00    3.0    4.0        10.0     1980.0  53.378933
# ...

# %%
columns = df.columns
complete_data=[]
for i in columns:
  tmp = len(df[df[i].isnull()])/len(df)*100
  complete_data.append(tmp)

import matplotlib.pyplot as plt
plt.figure(figsize = (10, 10))
plt.barh(columns,complete_data )
plt.title('Unompleteness of data')
plt.xlabel('Features')
plt.ylabel('Percentages of null data')
# Out:
# Text(0, 0.5, 'Percentages of null data')

# %%
df.drop(['id', 'condition', 'buildingMaterial'], axis=1, inplace=True)
df = df.dropna()

# %%
from sklearn.model_selection import train_test_split
#X = data.drop('Exercise Intensity', axis = 1)
#y = data['Exercise Intensity']
X_train, X_test = train_test_split(df,test_size=0.4,random_state=21)
X_valid, X_test = train_test_split(X_test,test_size=0.5,random_state=21)
print(len(X_train))
print(len(X_test))
print(len(X_valid))
X_train.describe()
# Out:
# 10958
# 3653
# 3653
#        squareMeters         rooms         floor    floorCount     buildYear  \
# count  10958.000000  10958.000000  10958.000000  10958.000000  10958.000000
# mean      57.902124      2.649389      3.388027      5.657510   1984.721847
# std       20.385397      0.886914      2.533667      3.369216     32.721082
# min       25.000000      1.000000      1.000000      1.000000   1864.000000
# 25%       44.292500      2.000000      2.000000      4.000000   1968.000000
# 50%       54.000000      3.000000      3.000000      4.000000   1988.000000
# 75%       67.322500      3.000000      4.000000      7.000000   2013.000000
# max      150.000000      6.000000     29.000000     29.000000   2023.000000
#
#            latitude     longitude  centreDistance      poiCount  \
# count  10958.000000  10958.000000    10958.000000  10958.000000
# mean      51.949080     19.648694        4.413139     20.394141
# std        1.301016      1.752935        2.750689     22.153757
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr = X_train.corr()
plt.figure(figsize = (15, 10))
sns.heatmap(corr, cmap = 'Greens', annot = True, fmt = '.2f')
# Out:
# <ipython-input-81-42665ddab281>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = X_train.corr()
# <Axes: >

# %%
import seaborn as sns
sns.set_theme()
sns.boxplot(X_train,x='hasElevator',y='floorCount')
# Out:
# <Axes: xlabel='hasElevator', ylabel='floorCount'>

# %%
tmp=X_train[X_train['hasElevator'] == 'no']
tmp=tmp[tmp['floorCount'] > 4]
X_train=X_train.drop(index=tmp.index).reset_index(drop='true')
X_train
# Out:
#            city               type  squareMeters  rooms  floor  floorCount  \
# 0        krakow       blockOfFlats         71.00    3.0    4.0         4.0
# 1        lublin       blockOfFlats         54.86    3.0    3.0         3.0
# 2       wroclaw       blockOfFlats         41.00    2.0    3.0         8.0
# 3        gdansk       blockOfFlats         97.00    4.0    2.0         2.0
# 4      warszawa       blockOfFlats         49.00    3.0    2.0        10.0
# ...         ...                ...           ...    ...    ...         ...
# 10569  katowice       blockOfFlats         32.32    2.0    4.0        10.0
# 10570  warszawa  apartmentBuilding         38.29    2.0    4.0         4.0
# 10571  katowice           tenement         61.00    3.0    1.0         4.0
# 10572      lodz       blockOfFlats         69.47    3.0    3.0         3.0
# 10573    gdansk       blockOfFlats         35.79    2.0    4.0         4.0
#
#        buildYear   latitude  longitude  centreDistance  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
cat_cols = X_train.select_dtypes(['object']).columns
cat_cols=cat_cols.drop(['type','city','ownership'])

df_cats = X_train[cat_cols].reset_index(drop=True)
cat_cols
X_train[df_cats.columns] = X_train[df_cats.columns].apply(LabelEncoder().fit_transform)
X_train
# Out:
#            city               type  squareMeters  rooms  floor  floorCount  \
# 0        krakow       blockOfFlats         71.00    3.0    4.0         4.0
# 1        lublin       blockOfFlats         54.86    3.0    3.0         3.0
# 2       wroclaw       blockOfFlats         41.00    2.0    3.0         8.0
# 3        gdansk       blockOfFlats         97.00    4.0    2.0         2.0
# 4      warszawa       blockOfFlats         49.00    3.0    2.0        10.0
# ...         ...                ...           ...    ...    ...         ...
# 10569  katowice       blockOfFlats         32.32    2.0    4.0        10.0
# 10570  warszawa  apartmentBuilding         38.29    2.0    4.0         4.0
# 10571  katowice           tenement         61.00    3.0    1.0         4.0
# 10572      lodz       blockOfFlats         69.47    3.0    3.0         3.0
# 10573    gdansk       blockOfFlats         35.79    2.0    4.0         4.0
#
#        buildYear   latitude  longitude  centreDistance  ...  \
# ...

# %%
X_train['priceForSquareMeters']=X_train['price']/X_train['squareMeters']
X_train
# Out:
#            city               type  squareMeters  rooms  floor  floorCount  \
# 0        krakow       blockOfFlats         71.00    3.0    4.0         4.0
# 1        lublin       blockOfFlats         54.86    3.0    3.0         3.0
# 2       wroclaw       blockOfFlats         41.00    2.0    3.0         8.0
# 3        gdansk       blockOfFlats         97.00    4.0    2.0         2.0
# 4      warszawa       blockOfFlats         49.00    3.0    2.0        10.0
# ...         ...                ...           ...    ...    ...         ...
# 10569  katowice       blockOfFlats         32.32    2.0    4.0        10.0
# 10570  warszawa  apartmentBuilding         38.29    2.0    4.0         4.0
# 10571  katowice           tenement         61.00    3.0    1.0         4.0
# 10572      lodz       blockOfFlats         69.47    3.0    3.0         3.0
# 10573    gdansk       blockOfFlats         35.79    2.0    4.0         4.0
#
# ...

# %%
from sklearn.decomposition import PCA
import seaborn as sns
sns.set_theme()
pca = PCA().set_output(transform="pandas").fit(X_train)
data_pca = pca.transform(X_train)
sns.scatterplot(x=data_pca['pca0'],y=data_pca['pca1'],label = 'Original data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-8fd3231808ed> in <cell line: 4>()
#       2 import seaborn as sns
#       3 sns.set_theme()
# ----> 4 pca = PCA().set_output(transform="pandas").fit(X_train)
#       5 data_pca = pca.transform(X_train)
#       6 sns.scatterplot(x=data_pca['pca0'],y=data_pca['pca1'],label = 'Original data')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py in fit(self, X, y)
#     433         self._validate_params()
#     434
# --> 435         self._fit(X)
#     436         return self
#     437
#
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     483             )
#     484
# --> 485         X = self._validate_data(
#     486             X, dtype=[np.float64, np.float32], ensure_2d=True, copy=self.copy
#     487         )
#
# ...
