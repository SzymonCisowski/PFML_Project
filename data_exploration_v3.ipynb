# %% [markdown]
# <a href="https://colab.research.google.com/github/SzymonCisowski/PFML_Project/blob/Hypothesis/data_exploration_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data2023_08 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DATASET/apartments_pl_2023_08.csv')
data2023_09 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DATASET/apartments_pl_2023_09.csv')
data2023_10 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DATASET/apartments_pl_2023_10.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data2023_10.describe()
# Out:
#        squareMeters         rooms         floor    floorCount     buildYear  \
# count  16690.000000  16690.000000  13644.000000  16448.000000  13785.000000
# mean      58.985279      2.680228      3.268030      5.162755   1984.573957
# std       21.347723      0.911191      2.455211      3.201862     34.164553
# min       25.000000      1.000000      1.000000      1.000000   1851.000000
# 25%       44.402500      2.000000      2.000000      3.000000   1965.000000
# 50%       55.000000      3.000000      3.000000      4.000000   1992.000000
# 75%       69.000000      3.000000      4.000000      6.000000   2015.000000
# max      150.000000      6.000000     29.000000     29.000000   2023.000000
#
#            latitude     longitude  centreDistance      poiCount  \
# count  16690.000000  16690.000000    16690.000000  16690.000000
# mean      52.047413     19.489039        4.328341     20.462912
# std        1.331076      1.779749        2.879183     24.104101
# ...

# %%
#merging 3 dataframes to 1
data = [data2023_08, data2023_09, data2023_10]
df = pd.concat(data)
print(df.shape)
df.describe()
df
# Out:
# (52592, 28)
#                                      id       city          type  \
# 0      f8524536d4b09a0c8ccc0197ec9d7bde   szczecin  blockOfFlats
# 1      accbe77d4b360fea9735f138a50608dd   szczecin  blockOfFlats
# 2      8373aa373dbc3fe7ca3b7434166b8766   szczecin      tenement
# 3      0a68cd14c44ec5140143ece75d739535   szczecin      tenement
# 4      f66320e153c2441edc0fe293b54c8aeb   szczecin  blockOfFlats
# ...                                 ...        ...           ...
# 16685  1e7f4f1fdfea31eb84e071d697839632  bydgoszcz           NaN
# 16686  d971c4ed3aab9919bf203e96019a678e  bydgoszcz      tenement
# 16687  60fcbfa2a2a48ebcc2e554efba7f2729  bydgoszcz      tenement
# 16688  cd0241b70b79aaaf767a0dd3a7cfbb31  bydgoszcz           NaN
# 16689  1cdf62d567c6be2fa488f16ad9939c3a  bydgoszcz  blockOfFlats
#
#        squareMeters  rooms  floor  floorCount  buildYear   latitude  \
# 0             63.00    3.0    4.0        10.0     1980.0  53.378933
# ...

# %%
#removing the duplicates due to the fact that flat sale offer might be still avaiable in 2/3 month in a row
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#                                      id       city          type  \
# 0      f8524536d4b09a0c8ccc0197ec9d7bde   szczecin  blockOfFlats
# 1      accbe77d4b360fea9735f138a50608dd   szczecin  blockOfFlats
# 2      8373aa373dbc3fe7ca3b7434166b8766   szczecin      tenement
# 3      0a68cd14c44ec5140143ece75d739535   szczecin      tenement
# 4      f66320e153c2441edc0fe293b54c8aeb   szczecin  blockOfFlats
# ...                                 ...        ...           ...
# 35227  f4f6e61a07541e8397d4baff8b770e0a  bydgoszcz      tenement
# 35228  15b7903dd521db04aae25831d5e6195d  bydgoszcz           NaN
# 35229  37c32bd102f6da4e24ae0caf366f1a9a  bydgoszcz  blockOfFlats
# 35230  a250aefc84e4567190067f387f56e966  bydgoszcz           NaN
# 35231  6a4b30b5fcdee00bfe5bcc0da82df9b1  bydgoszcz  blockOfFlats
#
#        squareMeters  rooms  floor  floorCount  buildYear   latitude  \
# 0             63.00    3.0    4.0        10.0     1980.0  53.378933
# ...

# %%
#creating new column for hypothesis purpose
df['priceForSquareMeter']=df['price']/df['squareMeters']
df
# Out:
#                                      id       city          type  \
# 0      f8524536d4b09a0c8ccc0197ec9d7bde   szczecin  blockOfFlats
# 1      accbe77d4b360fea9735f138a50608dd   szczecin  blockOfFlats
# 2      8373aa373dbc3fe7ca3b7434166b8766   szczecin      tenement
# 3      0a68cd14c44ec5140143ece75d739535   szczecin      tenement
# 4      f66320e153c2441edc0fe293b54c8aeb   szczecin  blockOfFlats
# ...                                 ...        ...           ...
# 35227  f4f6e61a07541e8397d4baff8b770e0a  bydgoszcz      tenement
# 35228  15b7903dd521db04aae25831d5e6195d  bydgoszcz           NaN
# 35229  37c32bd102f6da4e24ae0caf366f1a9a  bydgoszcz  blockOfFlats
# 35230  a250aefc84e4567190067f387f56e966  bydgoszcz           NaN
# 35231  6a4b30b5fcdee00bfe5bcc0da82df9b1  bydgoszcz  blockOfFlats
#
#        squareMeters  rooms  floor  floorCount  buildYear   latitude  \
# 0             63.00    3.0    4.0        10.0     1980.0  53.378933
# ...

# %%
df=df.dropna(subset=['hasElevator','hasBalcony','hasParkingSpace']) #droping NaN data in order to clean the data

# %% [markdown]
# BASIC DATA EXPLORATORY

# %%
#creating new dataframes with different features status (is feature included or excluded in df)
filtered_df_all = df.drop(df[(df['hasElevator'] == 'yes') | (df['hasParkingSpace'] == 'yes') | (df['hasBalcony'] == 'yes') ].index)
filtered_df_bps = df.drop(df[(df['hasElevator'] == 'no') | (df['hasParkingSpace'] == 'yes') | (df['hasBalcony'] == 'yes')].index)
filtered_df_eps = df.drop(df[(df['hasElevator'] == 'yes') | (df['hasParkingSpace'] == 'yes') | (df['hasBalcony'] == 'no')].index)
filtered_df_eb = df.drop(df[(df['hasElevator'] == 'yes') | (df['hasParkingSpace'] == 'no') | (df['hasBalcony'] == 'yes')].index)
filtered_df_none = df.drop(df[(df['hasElevator'] == 'no') | (df['hasParkingSpace'] == 'no') | (df['hasBalcony'] == 'no')].index)
filtered_df_all
# Out:
#                                      id       city          type  \
# 2      8373aa373dbc3fe7ca3b7434166b8766   szczecin      tenement
# 4      f66320e153c2441edc0fe293b54c8aeb   szczecin  blockOfFlats
# 13     9ebbaddd05ba76b732e7e4d99c2e3509   szczecin      tenement
# 15     d59165364f1c4b3d658890e808e7d77c   szczecin      tenement
# 18     e36ebbb4b3983c3c62c487456ead5957   szczecin  blockOfFlats
# ...                                 ...        ...           ...
# 35213  d5f5ec7de8d71d8a598010745e5b24b1  bydgoszcz  blockOfFlats
# 35218  4654cde0c8264c6fcd11f0adc8c14faf  bydgoszcz           NaN
# 35226  005af5d115e2a621cfb6ce60e3b973d3  bydgoszcz           NaN
# 35228  15b7903dd521db04aae25831d5e6195d  bydgoszcz           NaN
# 35229  37c32bd102f6da4e24ae0caf366f1a9a  bydgoszcz  blockOfFlats
#
#        squareMeters  rooms  floor  floorCount  buildYear   latitude  \
# 2             73.02    3.0    2.0         3.0        NaN  53.452222
# ...

# %%
#in order to do a plot analysis it is crucial to get some specific value of the column we want to check, therefore we use mean value for the price per square meter
mean_no_all=filtered_df_all['priceForSquareMeter'].mean()
mean_yes_elev=filtered_df_bps['priceForSquareMeter'].mean()
mean_yes_balcony=filtered_df_eps['priceForSquareMeter'].mean()
mean_yes_parkingspc=filtered_df_eb['priceForSquareMeter'].mean()
mean_yes_all=filtered_df_none['priceForSquareMeter'].mean()
mean_list=[mean_no_all,mean_yes_elev,mean_yes_balcony,mean_yes_parkingspc,mean_yes_all]
print(mean_list)
# Out:
# [11162.289827177761, 14190.518070776563, 10848.257644255962, 11085.356149618734, 14394.584874010083]

# %%
x=['Has 0 features','Has only elevator','Has only balcony','Has only parking space','Has all of the features']

# %%
import matplotlib.pyplot as plt
color = ['#98e06e', '#a8713d', '#6d9ed6', '#ba6aa5','#2dbdb2']
fig, ax = plt.subplots()
ax.bar(x, mean_list,color=color, align='center', width=0.3,edgecolor='#0d0d07ba')

ax.set_axisbelow(True)
ax.set_xticklabels(x,rotation=15)
ax.grid(color='gray', linestyle='dashed',axis='y')



plt.xlabel("Type of the condidtion")
plt.ylabel("Price per square meter")
plt.title("Comparison of the price per square meter with different features included in the flat")
plt.show()
# Out:
# <ipython-input-117-32ae01c60255>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x,rotation=15)

# %% [markdown]
# LOW SQUARE METER VALUE

# %%
#preparing the data to compare the price per square meter for flats below 35m2
import math
none_df_ls=filtered_df_all.drop(filtered_df_all[filtered_df_all['squareMeters'] >= 35].index)
elev_df_ls=filtered_df_bps.drop(filtered_df_bps[filtered_df_bps['squareMeters'] >= 35].index)
balc_df_ls=filtered_df_eps.drop(filtered_df_eps[filtered_df_eps['squareMeters'] >= 35].index)
parkspc_df_ls=filtered_df_eb.drop(filtered_df_eb[filtered_df_eb['squareMeters'] >= 35].index)
all_df_ls=filtered_df_none.drop(filtered_df_none[filtered_df_none['squareMeters'] >= 35].index)

# %%
#calculating the mean value of price per square meter for little apartments
mean_no_all_ls=none_df_ls['priceForSquareMeter'].mean()
mean_yes_elev_ls=elev_df_ls['priceForSquareMeter'].mean()
mean_yes_balcony_ls=balc_df_ls['priceForSquareMeter'].mean()
mean_yes_parkingspc_ls=parkspc_df_ls['priceForSquareMeter'].mean()
mean_yes_all_ls=all_df_ls['priceForSquareMeter'].mean()
mean_list_ls=[mean_no_all_ls,mean_yes_elev_ls,mean_yes_balcony_ls,mean_yes_parkingspc_ls,mean_yes_all_ls]
print(mean_list_ls)
# Out:
# [12837.220778894012, 15583.979535559472, 13134.950282885351, 12501.848457209455, 16533.960601339077]

# %%
import matplotlib.pyplot as plt
color = ['#339632', '#068769', '#e6770b', '#00FFDE','#FF4444']
fig, ax = plt.subplots()
ax.bar(x, mean_list_ls,color=color, align='center', width=0.3,edgecolor='#0d0d07ba')

ax.set_axisbelow(True)
ax.set_xticklabels(x,rotation=15)
ax.grid(color='gray', linestyle='dashed',axis='y')



plt.xlabel("Type of the condidtion")
plt.ylabel("Price per square meter")
plt.title("Comparison of the price per square meter with different features included in the flat")
plt.show()
# Out:
# <ipython-input-120-90d2a22574b9>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x,rotation=15)

# %% [markdown]
# HIGH SQUARE METER VALUE

# %%
none_df_hs=filtered_df_all.drop(filtered_df_all[filtered_df_all['squareMeters'] <=65].index)
elev_df_hs=filtered_df_bps.drop(filtered_df_bps[filtered_df_bps['squareMeters'] <=65].index)
balc_df_hs=filtered_df_eps.drop(filtered_df_eps[filtered_df_eps['squareMeters'] <=65].index)
parkspc_df_hs=filtered_df_eb.drop(filtered_df_eb[filtered_df_eb['squareMeters'] <=65].index)
all_df_hs=filtered_df_none.drop(filtered_df_none[filtered_df_none['squareMeters'] <=65].index)

# %%
#calculating the mean value of price per square meter for big apartments
mean_no_all_hs=none_df_hs['priceForSquareMeter'].mean()
mean_yes_elev_hs=elev_df_hs['priceForSquareMeter'].mean()
mean_yes_balcony_hs=balc_df_hs['priceForSquareMeter'].mean()
mean_yes_parkingspc_hs=parkspc_df_hs['priceForSquareMeter'].mean()
mean_yes_all_hs=all_df_hs['priceForSquareMeter'].mean()
mean_list_hs=[mean_no_all_hs,mean_yes_elev_hs,mean_yes_balcony_hs,mean_yes_parkingspc_hs,mean_yes_all_hs]
print(mean_list_hs)
# Out:
# [10328.601312482888, 13755.73961820162, 10506.526830060082, 10450.30194046148, 14193.235906847558]

# %%
import matplotlib.pyplot as plt
color = ['#D573D2', '#554dc4', '#95EF6E', '#00FFDE','#6b0909']
fig, ax = plt.subplots()
ax.bar(x, mean_list_hs,color=color, align='center', width=0.3,edgecolor='#0d0d07ba')

ax.set_axisbelow(True)
ax.set_xticklabels(x,rotation=15)
ax.grid(color='gray', linestyle='dashed',axis='y')



plt.xlabel("Type of the condidtion")
plt.ylabel("Price per square meter")
plt.title("Comparison of the price per square meter with different features included in the flat")
plt.show()
# Out:
# <ipython-input-123-f33c4e0b84c9>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x,rotation=15)

# %% [markdown]
# MEDIUM SQUARE METER VALUE

# %%
none_df_ms=filtered_df_all.drop(filtered_df_all[(filtered_df_all['squareMeters'] >65) |(filtered_df_all['squareMeters'] <35)].index)
elev_df_ms=filtered_df_bps.drop(filtered_df_bps[(filtered_df_bps['squareMeters'] >65) |(filtered_df_bps['squareMeters'] <35)].index)
balc_df_ms=filtered_df_eps.drop(filtered_df_eps[(filtered_df_eps['squareMeters'] >65) |(filtered_df_eps['squareMeters'] <35)].index)
parkspc_df_ms=filtered_df_eb.drop(filtered_df_eb[(filtered_df_eb['squareMeters'] >65) |(filtered_df_eb['squareMeters'] <35)].index)
all_df_ms=filtered_df_none.drop(filtered_df_none[(filtered_df_none['squareMeters'] >65)|(filtered_df_none['squareMeters'] <35)].index)

# %%
#calculating the mean value of price per square meter for big apartments
mean_no_all_ms=none_df_ms['priceForSquareMeter'].mean()
mean_yes_elev_ms=elev_df_ms['priceForSquareMeter'].mean()
mean_yes_balcony_ms=balc_df_ms['priceForSquareMeter'].mean()
mean_yes_parkingspc_ms=parkspc_df_ms['priceForSquareMeter'].mean()
mean_yes_all_ms=all_df_ms['priceForSquareMeter'].mean()
mean_list_ms=[mean_no_all_ms,mean_yes_elev_ms,mean_yes_balcony_ms,mean_yes_parkingspc_ms,mean_yes_all_ms]
print(mean_list_ms)
# Out:
# [11117.54646893762, 13959.802382269932, 10837.361855477706, 11185.830402696616, 14305.949977720178]

# %%
import matplotlib.pyplot as plt
color = ['#339632', '#858248', '#e34aed', '#5e525e','#FF4444']
fig, ax = plt.subplots()
ax.bar(x, mean_list_ms,color=color, align='center', width=0.3,edgecolor='#0d0d07ba')

ax.set_axisbelow(True)
ax.set_xticklabels(x,rotation=15)
ax.grid(color='gray', linestyle='dashed',axis='y')



plt.xlabel("Type of the condidtion")
plt.ylabel("Price per square meter")
plt.title("Comparison of the price per square meter with different features included in the flat")
plt.show()
# Out:
# <ipython-input-126-9c6e0ce9774f>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(x,rotation=15)
